# %%
# !pip install -q -U google-generativeai

# %%
import google.generativeai as genai

genai.configure(api_key="AIzaSyDCLWWrM-lKZg-bpVwwVuSAKZmChXMSiPo")
model = genai.GenerativeModel("gemini-1.5-flash")
# Out:
# You can't directly feed a PDF file to me. I'm a large language model; I don't have the capability to interact with your local file system or open PDF files.  To get a summary, you need to first extract the text from the PDF.  Then, you can paste that text into our conversation.
#
# There's no "code" in the sense of a program you run *on me*.  I process natural language. Here's how you would ask me to summarize a PDF, broken down into steps:
#
# **1. Extract Text from PDF:**
#
# You'll need to use a PDF to text converter.  Many free and paid options exist. Some popular ones include:
#
# * **Online converters:**  Search for "online PDF to text converter."  Many websites offer this service.
# * **Software:**  Applications like Adobe Acrobat Pro (paid), LibreOffice (free, open-source), and others can extract text.
# * **Python libraries:**  If you're comfortable with Python programming, libraries like `PyPDF2`, `tika`, or `pdfplumber` can extract text programmatically.
#
# ...

# %%
import PyPDF2

def extract_text_from_pdf(pdf_path):
    """Extracts text from a PDF file.

    Args:
        pdf_path: Path to the PDF file.

    Returns:
        The extracted text as a string, or None if an error occurs.
    """
    try:
        with open(pdf_path, 'rb') as pdf_file:
            reader = PyPDF2.PdfReader(pdf_file)
            text = ""
            for page in reader.pages:
                text += page.extract_text()
            return text
    except FileNotFoundError:
        print(f"Error: PDF file not found at {pdf_path}")
        return None
    except PyPDF2.errors.PdfReadError:
        print(f"Error: Could not read PDF file at {pdf_path}")
        return None

# Example usage:
pdf_file_path = "/content/PADG_162024.pdf"  # Replace with your PDF file path
extracted_text = extract_text_from_pdf(pdf_file_path)

if extracted_text:
    print("Extracted text:\n", extracted_text) #Then copy and paste this output into our chat
# Out:
# Extracted text:
#
#
# PERATURAN ANGGOTA DEWAN GUBERNUR
# NOMOR  16 TAHUN  2024
# TENTANG
# TRANSAKSI PASAR VALUTA ASING  BERDASARKAN PRINSIP SYARIAH
#
# DENGAN RAHMAT TUHAN YANG MAHA ESA
#
# ANGGOTA DEWAN GUBERNUR BANK INDONESIA,
#
# Menimbang  : a. bahwa dalam mewujudkan tujuan untuk mencapai
# stabilitas nilai rupiah, Bank Indonesia menetapkan  dan
# melaksanakan kebijakan moneter secara berkelanjutan,
# konsisten, dan transparan , yang salah satunya dilakukan
# melalui pengaturan, pengembangan , dan pengawasan
# pasar valuta asing  berdasarkan prinsip syariah ;
#   b.  bahwa pengaturan, pengembangan , dan pengawasan
# pasar valuta asing berdasarkan prinsip syariah bertujuan
# untuk membangun pasar valuta asing  berdasarkan
# prinsip syariah  yang modern dan maju ;
#   c.  bahwa untuk mendorong pasar valuta asing  berdasarkan
# prinsip syariah  yang modern dan maju  diperlukan
# pengaturan pasar valuta asing berdasarkan prinsip
# syariah yang disusun dengan mempertimbangkan
# ...

# %%
response = model.generate_content(f"dapatkah anda membuatkan saya sebuah summary dari text ini menjadi latar belakang dan tujuan, dan bagian pokok pokok peraturan dengan catatan gunakan prespektif perbankan? \n{extracted_text}")
print(response.text)
# Out:
# **Latar Belakang dan Tujuan**
#
# Dari perspektif perbankan, Peraturan Anggota Dewan Gubernur (PADG) Nomor 16 Tahun 2024 tentang Transaksi Pasar Valuta Asing Berdasarkan Prinsip Syariah bertujuan untuk menciptakan pasar valuta asing syariah yang modern dan maju di Indonesia.  Hal ini didorong oleh kebutuhan untuk mendukung stabilitas nilai rupiah melalui pengaturan, pengembangan, dan pengawasan transaksi valuta asing berbasis syariah yang konsisten, transparan, dan hati-hati.  Peraturan ini juga merespon dinamika ekonomi global dan kebutuhan pelaku pasar, sekaligus mempertimbangkan prinsip kehati-hatian dalam perbankan syariah.  PADG ini mencabut dan menggantikan PADG Nomor 24/13/PADG/2022.
#
# **Pokok-Pokok Peraturan (Perspektif Perbankan):**
#
# Peraturan ini mengatur berbagai aspek transaksi valuta asing syariah bagi bank umum syariah (BUS) dan unit usaha syariah (UUS), yang secara umum disebut "Bank" dalam peraturan ini.  Pokok-pokoknya meliputi:
#
# ...

# %%
template_tabel = '''
latar belakang dan tujuan | response
pokok pokok peraturan | response
'''

# %%
tabel1 = model.generate_content(f"dapatkah anda membuat kan sebuah table yang berisikan 2 baris, latar belakang dan tujuan sebagai baris pertama, dan pokok pokok peraturan sebagai baris kedua dari text ini, jangan sampai terbalik templatenya seperti ini {template_tabel}\n{response}, untuk isi dari pokok pokok peraturan dapatkah membuatnya menjadi sebuah list yang ada dalam cell tabel ?")
print(tabel1.text)
# Out:
# Berikut tabel yang berisi Latar Belakang dan Tujuan serta Pokok-Pokok Peraturan, dengan Pokok-Pokok Peraturan disajikan dalam bentuk daftar (list) di dalam sel tabel:
#
# | Latar Belakang dan Tujuan | Pokok-Pokok Peraturan (Perspektif Perbankan) |
# |---|---|
# ...

# %%
response2 = model.generate_content(f"dapatkah anda membuatkan saya sebuah recomended action plan dengan catatan gunakan prespektif perbankan respon dengan bahasa indonesia? \n{extracted_text}")
print(response2.text)
# Out:
# ## Rencana Aksi Perbankan Respon Terhadap Peraturan Anggota Dewan Gubernur Nomor 16 Tahun 2024
#
# Peraturan Anggota Dewan Gubernur (PADG) Nomor 16 Tahun 2024 tentang Transaksi Pasar Valuta Asing Berdasarkan Prinsip Syariah membawa perubahan signifikan dalam operasional perbankan syariah dan unit usaha syariah (UUS).  Berikut rencana aksi yang direkomendasikan bagi perbankan untuk merespon regulasi tersebut:
#
# **Fase 1: Pemahaman dan Analisis (1-4 minggu)**
#
# * **Tujuan:** Memahami secara menyeluruh isi PADG Nomor 16 Tahun 2024 dan implikasinya terhadap operasional bank.
# * **Aksi:**
#     * Mengadakan pelatihan internal bagi seluruh divisi terkait (Treasury, Syariah Compliance, Legal, IT, Operasional) untuk memahami isi PADG dan perubahan yang diperlukan.
#     * Melakukan analisis mendalam terhadap setiap pasal dan bab PADG, khususnya yang berkaitan dengan:
#         * Jenis transaksi yang diperbolehkan dan dilarang.
#         * Ketentuan *Underlying Transaction*.
# ...

# %%
tabel2_template = '''
recomended action plan | respon
Tujuan | respon
'''

# %%
tabel2 = model.generate_content(f"dapatkah anda membuat kan sebuah table yang berisikan beberapa baris, recomended action plan sebagai baris pertama, dan respon sebagai baris kedua dari text ini, tolong hilangkan kata kata fase fase,jangan sampai terbalik templatenya seperti ini {tabel2_template}\n{response2}")
print(tabel2.text)
# Out:
# | Recommended Action Plan | Respon |
# |---|---|
# | Memahami secara menyeluruh isi PADG Nomor 16 Tahun 2024 dan implikasinya terhadap operasional bank. | Mengadakan pelatihan internal; Melakukan analisis mendalam terhadap setiap pasal dan bab PADG; Mengidentifikasi kesenjangan antara praktik operasional saat ini dengan ketentuan yang baru; Mengkaji ulang prosedur internal, sistem, dan teknologi; Melakukan konsultasi dengan Dewan Pengawas Syariah (DPS).  Penanggung jawab: Divisi Syariah Compliance dan Legal. Indikator keberhasilan: Seluruh divisi terkait memahami PADG, dan analisis kesenjangan operasional telah selesai. |
# ...

# %%
comparedto = "/content/PADG_241322.pdf"  # Replace with your PDF file path
compared_text = extract_text_from_pdf(comparedto)

# %%
response3 = model.generate_content(f"saya memiliki 2 text regulasi, saya ingin anda membuatkan sebuah komparasi akan regulasi dengan prepektif perbankan, buatkan 3 poin utama yang dapat dibandingkan dah kemudian buatlah 3 sub-comparsion dengan judul atau kategori yang cocok untuk setiap poin utama yang dibandingkan, gunakan bahasa indonesia dan ini merupakan text yang akan dikomparasi dan sertakan kesimpulan diakhir setiap poin\n{extracted_text} \n\n\n\n{compared_text}")
print(response3.text)
# Out:
# Berikut adalah komparasi antara Peraturan Anggota Dewan Gubernur Nomor 16 Tahun 2024 (PAG 16/2024) tentang Transaksi Pasar Valuta Asing Berdasarkan Prinsip Syariah dan Peraturan Anggota Dewan Gubernur Nomor 24/13/PADG/2022 (PAG 24/2022) tentang Peraturan Pelaksanaan Transaksi di Pasar Valuta Asing Berdasarkan Prinsip Syariah, dari perspektif perbankan.  Komparasi ini difokuskan pada tiga poin utama dengan tiga sub-komparasi masing-masing.
#
# **Poin Utama 1: Jenis dan Mekanisme Transaksi Lindung Nilai Syariah**
#
# ...

# %%
tabel3 = model.generate_content(f"dapatkah anda menjadikan ini 3 buah tabel, bergantung dengan poin utama yang dibandingkan dari {response3}")
print(tabel3.text)
# Out:
# Berikut adalah tiga tabel yang membandingkan PAG 16/2024 dan PAG 24/2022 berdasarkan tiga poin utama yang dibahas:
#
# **Tabel 1: Jenis dan Mekanisme Transaksi Lindung Nilai Syariah**
#
# | Fitur                                      | PAG 16/2024                                                                                                                            | PAG 24/2022                                                                        | Kesimpulan                                                                                                                                       |
# ...

# %%
# !pip install mistune weasyprint
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.0/300.0 kB 7.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 33.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 77.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.1/849.1 kB 30.3 MB/s eta 0:00:00
# ...

# %%
from rich.console import Console
from rich.markdown import Markdown

# Create a rich console
console = Console()

# Parse and render the Markdown
markdown = Markdown(tabel1.text)
console.print(markdown)
# Out:
# Berikut tabel yang berisi Latar Belakang dan Tujuan serta Pokok-Pokok Peraturan, dengan Pokok-Pokok Peraturan
# disajikan dalam bentuk daftar (list) di dalam sel tabel:
#
#
#
#
#
#
#
#
#
#
#   Latar Belakang dan Tujuan                                Pokok-Pokok Peraturan (Perspektif Perbankan)
#  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   Dari perspektif perbankan, Peraturan Anggota Dewan       * Definisi: Definisi istilah kunci, termasuk jenis
#   Gubernur (PADG) Nomor 16 Tahun 2024 tentang Transaksi    transaksi lindung nilai syariah (sederhana dan
#   Pasar Valuta Asing Berdasarkan Prinsip Syariah           kompleks), serta Underlying Transaksi. * Kontrak dan
#   bertujuan untuk menciptakan pasar valuta asing syariah   Konfirmasi:  Penggunaan kontrak keuangan tertulis yang
#   yang modern dan maju di Indonesia.  Hal ini didorong     memenuhi prinsip syariah dan konfirmasi tertulis.
# ...

# %%
markdown = Markdown(tabel2.text)
console.print(markdown)
# Out:
#
#   Recommended Action Plan                                  Respon
#  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   Memahami secara menyeluruh isi PADG Nomor 16 Tahun       Mengadakan pelatihan internal; Melakukan analisis
#   2024 dan implikasinya terhadap operasional bank.         mendalam terhadap setiap pasal dan bab PADG;
#                                                            Mengidentifikasi kesenjangan antara praktik
#                                                            operasional saat ini dengan ketentuan yang baru;
#                                                            Mengkaji ulang prosedur internal, sistem, dan
#                                                            teknologi; Melakukan konsultasi dengan Dewan Pengawas
#                                                            Syariah (DPS).  Penanggung jawab: Divisi Syariah
# ...

# %%
markdown = Markdown(tabel3.text)
console.print(markdown)
# Out:
# Berikut adalah tiga tabel yang membandingkan PAG 16/2024 dan PAG 24/2022 berdasarkan tiga poin utama yang dibahas:
#
# Tabel 1: Jenis dan Mekanisme Transaksi Lindung Nilai Syariah
#
#
#   Fitur                        PAG 16/2024                 PAG 24/2022                  Kesimpulan
#  ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#   Jenis Transaksi Lindung      Transaksi Lindung Nilai     Transaksi Lindung Nilai      PAG 16/2024 lebih
#   Nilai                        Sederhana, Transaksi        Sederhana, Transaksi         komprehensif, khususnya
#                                Lindung Nilai Kompleks,     Lindung Nilai Kompleks       dengan penambahan
#                                Transaksi Lindung Nilai                                  transaksi melalui bursa
#                                Melalui Bursa Komoditi                                   komoditi syariah.
# ...
